# %%
import faultier
import serial
ft = faultier.Faultier()
ser = serial.Serial(ft.get_serial_path(), baudrate=115200)
ser.timeout = 0.3


ft.configure_glitcher(
    power_cycle_output = faultier.OUT_MUX0,
    power_cycle_length = 300000
)

ft.power_cycle()
print(ser.read(100).hex())
# Out:
# 005253544f4b41590000000004000000c41100205555555514560000c458000000000000c01100200000000008000000000000000000000001000000fd030000

# %%
import struct
from tqdm.notebook import trange
ft.configure_glitcher(
    trigger_source = faultier.TRIGGER_IN_EXT0,
    trigger_type = faultier.TRIGGER_PULSE_POSITIVE,
    glitch_output= faultier.OUT_CROWBAR
)
while True:
    for d in range(50, 160):
        for p in range(0, 10):
            ser.reset_input_buffer()
            ft.glitch(delay=d, pulse=p)
            data = ser.read(64) # 0 byte + RST + OKAY + 14*4
            if(len(data)) != 64:
                continue
            if(data[1:4] != b"RST"):
                pass
                continue
            if(data[4:8] != b"OKAY"):
                continue
            # if b"\xaa\xaa\xaa\xaa" in data:
            #     print(f"{d} {p} {data.hex()}")
            values = struct.unpack("<IIIIIIIIIIIIII", data[8:])
            for i in range(0, 14):
                if i == 3:
                    continue
                if values[i] == 0x55555555:
                    print(f"{d} {p} VALUE IN REGISTER {i}")
            # if(values[3] != 0x55555555):
            #     print(f"{d} {p} {hex(values[3])}")
        
            # if(data[4:9] != b"\x55\x55\x55\x55"):
            #     value = struct.unpack("<I", data[4:])[0]
            #     if value == 0x54535200:
            #         # print(f"Reset {d} {p}")
            #         continue
            #     print(f"{d} {p} {hex(value)}")
# Out:
#   0%|          | 0/110 [00:00<?, ?it/s]
# 81 6 0xaaaaaaff
# 85 5 0xaaaaaaff
# 103 6 0xaaaaaaff
# 105 6 0xaaaaaaff
# 105 8 0xaaaaaaff
# 106 6 0xaaaaaaff
# 108 5 0xaaaaaaff
# 138 7 0x140555d5
# 140 7 0xaaaaaaaa
# 141 6 0xaaaaaaaa
# 144 5 0x1
#   0%|          | 0/110 [00:00<?, ?it/s]
# 81 5 0xaaaaaaff
# 86 7 0xaaaaaaff
# 98 6 0xaaaaaaff
# 103 6 0xaaaaaaff
# 105 6 0xaaaaaaff
# 107 6 0xaaaaaaff
# 112 9 0xaaaaaaaa
# 132 6 0xaaaaaaff
# 137 5 0x55555551
# 138 6 0xaaaaaaaa
# 146 5 0x555555aa
# 153 6 0x555555aa
# 153 7 0x555555aa
#   0%|          | 0/110 [00:00<?, ?it/s]
# 82 5 0xaaaaaaff
# 91 6 0xaaaaaaff
# 98 6 0xaaaaaaff
# 99 6 0xaaaaaaff
# 102 7 0xaaaaaaff
# 104 7 0xaaaaaaff
# 104 8 0xaaaaaaff
# 104 9 0xaaaaaaff
# 111 5 0xaaaaaaff
# 111 7 0xaaaaaaaa
# 111 8 0xaaaaaaff
# 131 5 VALUE IN REGISTER 11
# 135 9 0xaaaaaaaa
# 136 7 0x40000000
# 136 8 0xaaaaaaaa
# 136 9 0xaaaaaaaa
# 138 9 0x74000000
# 144 5 0x555555aa
# 147 5 0x555555aa
# 153 6 0x555555aa
#   0%|          | 0/110 [00:00<?, ?it/s]
# 104 5 0xaaaaaaff
# 105 6 0xaaaaaaff
# 123 6 0x50505050
# 136 7 0x0
# 136 8 0x0
# 144 5 0x555555aa
# 154 7 0x555555aa
#   0%|          | 0/110 [00:00<?, ?it/s]
# 81 6 0xaaaaaaff
# 91 6 0xaaaaaaff
# 93 9 0xaaaaaaff
# 104 8 0xaaaaaaff
# 108 5 0xaaaaaaff
# 111 5 0xaaaaaaff
# 135 6 0x103
# 135 9 0xaaaaaaaa
# 139 8 0x57555555
# 144 5 0x555555aa
# 145 5 0x555555aa
# 146 5 0x555555aa
# 147 8 VALUE IN REGISTER 7
# 147 8 0x1
# 153 7 0x555555aa
#   0%|          | 0/110 [00:00<?, ?it/s]
# 80 6 0xaaaaaaff
# 84 5 0xaaaaaaff
# 86 7 0xaaaaaaff
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[43], line 13
#      11 ser.reset_input_buffer()
#      12 ft.glitch(delay=d, pulse=p)
# ---> 13 data = ser.read(64) # 0 byte + RST + OKAY + 14*4
#      14 if(len(data)) != 64:
#      15     continue
#
# File ~/miniforge3/envs/glitching2/lib/python3.11/site-packages/serial/serialposix.py:565, in Serial.read(self, size)
#     563 while len(read) < size:
#     564     try:
# --> 565         ready, _, _ = select.select([self.fd, self.pipe_abort_read_r], [], [], timeout.time_left())
#     566         if self.pipe_abort_read_r in ready:
#     567             os.read(self.pipe_abort_read_r, 1000)
#
# KeyboardInterrupt:

# %%
import struct
from tqdm.notebook import trange
ft.configure_glitcher(
    trigger_source = faultier.TRIGGER_IN_EXT0,
    trigger_type = faultier.TRIGGER_PULSE_POSITIVE,
    glitch_output= faultier.OUT_CROWBAR
)

ser.reset_input_buffer()
ft.glitch(delay=156, pulse=6)
data = ser.read(8) # 0 byte + RST + 4 byte number
if(data[1:4] != b"RST"):
    pass
if(data[4:8] == b"RST") or (data[4:8] == b"\x00RS"):
    print("Reset {d} {p}")
if(data[4:9] != b"\x55\x55\x55\x55"):
    value = struct.unpack("<I", data[4:])[0]
    if value == 0x54535200:
        print(f"Reset {d} {p}")
    print(f"{d} {p} {hex(value)}")
# Out:
# 221 5 0xaaaaaaaa
