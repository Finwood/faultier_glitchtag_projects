# %%
import faultier
import serial
import time

ft = faultier.Faultier()
ser = serial.Serial(ft.get_serial_path(), baudrate=115200)
ser.timeout = 0.1

ser.reset_input_buffer()

ft.configure_glitcher(
    power_cycle_output = faultier.OUT_MUX0,
    power_cycle_length = 300000
)

ft.power_cycle()
d = ser.readline()
print(d)
# Out:
# b'RSTOKAY55555555\n'

# %%
ft.configure_glitcher(
    trigger_source = faultier.TRIGGER_IN_EXT0,
    trigger_type = faultier.TRIGGER_PULSE_POSITIVE,
    glitch_output= faultier.OUT_CROWBAR
)

for delay in range(1, 200000):
    for pulse in range(0, 20):
        # Flush potentially left-over data in serial input buffer
        ser.reset_input_buffer()

        # Glitch with our delay and pulse
        ft.glitch(delay, pulse)

        # Read in 16 bytes of data
        data = ser.read(16)

        # Ignore regular execution
        if(data == b'RSTOKAY55555555\n'):
            continue
        
        # Print result
        print(f"{delay} {pulse} {data}")
# Out:
# 1 5 b'RST\x80\x14'
# 2 5 b'RST\x80\x14'
# 2 6 b'RST'
# 2 8 b'RST'
# 3 7 b'RST'
# 3 8 b'RST4R\x14'
# 4 7 b'RST4R\x14'
# 4 8 b'RST'
# 5 5 b'RST'
# 5 6 b'RST4R\x14'
# 5 7 b'RST4R\x14'
# 5 8 b'RST\x80\x14'
# 6 6 b'RST4R\x14'
# 6 7 b'RST4R\x14'
# 6 8 b'RST'
# 7 7 b'RST'
# 7 8 b'RST'
# 8 6 b'RST\x80\x14'
# 8 7 b'RST'
# 9 6 b'RST'
# 9 7 b'RST'
# 10 7 b'RST\x80\x14'
# 10 8 b'RST'
# 11 8 b'RST4R\x14'
# 12 8 b'RST'
# 13 7 b'RST\x80\x14'
# 13 8 b'RST'
# 14 6 b'RST4R\x14'
# 14 7 b'RST\x80\x14'
# 14 8 b'RST'
# 15 7 b'RSTOKAY00000000\n'
# 16 8 b'RST\x80\x14'
# 17 6 b'RST\x80\x14'
# 17 7 b'RST'
# 18 6 b'RST'
# 18 8 b'RST'
# 19 7 b'RST'
# 19 8 b'RST4R\x14'
# 20 6 b'RST'
# 20 7 b'RST4R\x14'
# 20 8 b'RST'
# 21 5 b'RST'
# 21 6 b'RST4R\x14'
# 21 8 b'RST\x80\x14'
# 22 7 b'RST\x80\x14'
# 23 7 b'RST\x80\x14'
# 24 6 b'RST\x80\x14'
# 24 7 b'RST\x80\x14'
# 25 5 b'RST\x80\x14'
# 25 7 b'RST4ROKAY200006A'
# 25 8 b'E\nRST'
# 26 5 b'RST\x80\x14'
# 26 8 b'RST4R\x14'
# 27 8 b'RST4R\x14'
# 28 7 b'RST4R\x14'
# 29 6 b'RST'
# 29 7 b'RST'
# 29 8 b'RST'
# 30 7 b'RST\x80\x14'
# 30 8 b'RST'
# 31 7 b'RST\x80\x14'
# 31 8 b'RST'
# 32 6 b'RST\x80\x14'
# 32 7 b'RST\x80\x14'
# 32 8 b'RST\x80\x14'
# 33 7 b'RST\x80\x14'
# 34 6 b'RST'
# 34 8 b'RST4R\x14'
# 35 8 b'RST4R\x14'
# 36 7 b'RST4R\x14'
# 36 8 b'RST'
# 37 6 b'RST4R\x14'
# 37 7 b'RST'
# 37 8 b'RST'
# 38 7 b'RST'
# 39 6 b'RST\x80\x14'
# 40 5 b'RST\x80\x14'
# 40 7 b'RST'
# 41 5 b'RST\x80\x14'
# 41 6 b'RST'
# 41 7 b'RST\x80\x14'
# 41 8 b'RST'
# 42 5 b'RST\x80\x14'
# 42 8 b'RST4R\x14'
# 43 8 b'RST4R\x14'
# 44 7 b'RST'
# 44 8 b'RST\x80\x14'
# 45 7 b'RST'
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[244], line 16
#      13 ft.glitch(delay, pulse)
#      15 # Read in 16 bytes of data
# ---> 16 data = ser.read(16)
#      18 # Ignore regular execution
#      19 if(data == b'RSTOKAY55555555\n'):
#
# File ~/miniforge3/envs/hextree/lib/python3.13/site-packages/serial/serialposix.py:565, in Serial.read(self, size)
#     563 while len(read) < size:
#     564     try:
# --> 565         ready, _, _ = select.select([self.fd, self.pipe_abort_read_r], [], [], timeout.time_left())
#     566         if self.pipe_abort_read_r in ready:
#     567             os.read(self.pipe_abort_read_r, 1000)
#
# KeyboardInterrupt:
