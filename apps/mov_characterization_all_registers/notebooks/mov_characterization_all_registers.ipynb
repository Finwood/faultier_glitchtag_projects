# %%
import faultier
import serial
import time

ft = faultier.Faultier()
ser = serial.Serial(ft.get_serial_path(), baudrate=115200)
ser.timeout = 0.01

ser.reset_input_buffer()

ft.configure_glitcher(
    power_cycle_output = faultier.OUT_MUX0,
    power_cycle_length = 300000
)

ft.power_cycle()
d = ser.readline()
print(d)
# Out:
# b'RSTOKAY55555555\n'

# %%
ft.configure_glitcher(
    trigger_source = faultier.TRIGGER_IN_EXT0,
    trigger_type = faultier.TRIGGER_PULSE_POSITIVE,
    glitch_output= faultier.OUT_CROWBAR
)

for delay in range(50, 120):
    for pulse in range(0, 10):
        # Flush potentially left-over data in serial input buffer
        ser.reset_input_buffer()

        # Glitch with our delay and pulse
        ft.glitch(delay, pulse)

        # Read in 16 bytes of data
        data = ser.read(16)

        # Ignore regular execution
        if(data == b'RSTOKAY55555555\n'):
            continue
        if(data == b'RST'):
            continue
        if(data[3:7] != b'OKAY'):
            continue
        # Print result
        print(f"{delay} {pulse} {data}")
# Out:
# 64 6 b'RSTOKAYAAAAAAFF\n'
# 68 6 b'RSTOKAYAAAAAAFF\n'
# 70 5 b'RSTOKAYAAAAAAFF\n'
# 70 6 b'RSTOKAYAAAAAAFF\n'
# 70 9 b'RSTOKAYAAAAAAAA\n'
# 71 5 b'RSTOKAYAAAAAAFF\n'
# 72 5 b'RSTOKAYAAAAAAFF\n'
# 73 6 b'RSTOKAYAAAAAAFF\n'
# 73 7 b'RSTOKAYAAAAAAFF\n'
# 73 9 b'RSTOKAYAAAAAAFF\n'
# 74 8 b'RSTOKAYAAAAAAFF\n'
# 75 5 b'RSTOKAYAAAAAAFF\n'
# 77 5 b'RSTOKAYAAAAAAFF\n'
# 81 7 b'RSTOKAYAAAAAAAA\n'
# 82 5 b'RSTOKAYAAAAAAAA\n'
# 85 7 b'RSTOKAYAAAAAAFF\n'
# 86 6 b'RSTOKAYAAAAAAFF\n'
# 86 9 b'RSTOKAY555555AA\n'
# 87 5 b'RSTOKAY555555AA\n'
# 87 9 b'RSTOKAY200000AD\n'
# 88 5 b'RSTOKAY555555AA\n'
# 88 7 b'RSTOKAYAAAAAAAA\n'
# 88 9 b'RSTOKAYAAAAAAFF\n'
# 90 9 b'RSTOKAYAAAAAAAA\n'
# 91 9 b'RSTOKAYAAAAAAAA\n'
# 92 5 b'RSTOKAY555555AA\n'
# 93 5 b'RSTOKAY555555AA\n'
# 103 6 b'RSTOKAY555555A9\n'
# 104 8 b'RSTOKAY555555AA\n'
# 106 6 b'RSTOKAY555555AA\n'
